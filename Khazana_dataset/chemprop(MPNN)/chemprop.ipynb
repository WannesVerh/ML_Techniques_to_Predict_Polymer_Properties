# %% [markdown]
# this jupiter notebook is for experimenting with chemprop

# %%
import chemprop
from chemprop.featurization import MolGraph

# %%
arguments = [
    '--data_path', 'csv_files/Polymers_Eat.csv',
    '--dataset_type', 'regression',
    '--save_dir', 'Checkpoints_Eat',
    '--num_folds', '5'
]

# %%
args = chemprop.args.TrainArgs().parse_args(arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python C:\Users\wanne\AppData\Roaming\Python\Python310\site-packages\ipykernel_launcher.py --f=c:\Users\wanne\AppData\Roaming\jupyter\runtime\kernel-v2-10484YW81m3BvJvC1.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'csv_files/Polymers_Eat.csv',
#  'data_weights_path': None,
#  'dataset_type': 'regression',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 30,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'mse',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'rmse',
#  'metrics': ['rmse'],
#  'minimize_score': True,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 5,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'Checkpoints_Eat',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['Eat'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# 390it [00:00, 77983.34it/s]
# 100%|██████████| 390/390 [00:00<00:00, 64914.42it/s]
# 100%|██████████| 390/390 [00:00<00:00, 10236.28it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# Total size = 390 | train size = 312 | val size = 39 | test size = 39
# Fitting scaler
# Building model 0
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=433, out_features=300, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 355,201
#   0%|          | 0/30 [00:00<?, ?it/s]Epoch 0
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.269621
#   3%|▎         | 1/30 [00:00<00:28,  1.02it/s]Epoch 1
# Loss = 4.9524e-01, PNorm = 34.0367, GNorm = 5.8949, lr_0 = 1.0000e-03
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.180477
#   7%|▋         | 2/30 [00:01<00:20,  1.34it/s]Epoch 2
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.175057
#  10%|█         | 3/30 [00:02<00:18,  1.50it/s]Epoch 3
# Loss = 1.9783e-01, PNorm = 34.0841, GNorm = 0.5301, lr_0 = 8.4834e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.155382
#  13%|█▎        | 4/30 [00:02<00:16,  1.57it/s]Epoch 4
# Loss = 1.5894e-01, PNorm = 34.1166, GNorm = 0.6723, lr_0 = 7.2962e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.152049
#  17%|█▋        | 5/30 [00:03<00:15,  1.66it/s]Epoch 5
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.127462
#  20%|██        | 6/30 [00:04<00:21,  1.13it/s]Epoch 6
# Loss = 9.1617e-02, PNorm = 34.1410, GNorm = 0.6622, lr_0 = 6.2751e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.124463
#  23%|██▎       | 7/30 [00:05<00:18,  1.22it/s]Epoch 7
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.109621
#  27%|██▋       | 8/30 [00:05<00:16,  1.36it/s]Epoch 8
# Loss = 2.7033e-02, PNorm = 34.1663, GNorm = 1.5388, lr_0 = 5.3234e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.100677
#  30%|███       | 9/30 [00:06<00:14,  1.46it/s]Epoch 9
# Loss = 6.0310e-02, PNorm = 34.1833, GNorm = 1.1763, lr_0 = 4.6416e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.096233
#  33%|███▎      | 10/30 [00:07<00:13,  1.52it/s]Epoch 10
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.088408
#  37%|███▋      | 11/30 [00:07<00:11,  1.60it/s]Epoch 11
# Loss = 4.8576e-02, PNorm = 34.1980, GNorm = 3.0190, lr_0 = 3.9377e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.088261
#  40%|████      | 12/30 [00:08<00:10,  1.66it/s]Epoch 12
# Loss = 4.0376e-02, PNorm = 34.2081, GNorm = 2.1901, lr_0 = 3.3866e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.072880
#  43%|████▎     | 13/30 [00:08<00:10,  1.66it/s]Epoch 13
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.074117
#  47%|████▋     | 14/30 [00:09<00:11,  1.43it/s]Epoch 14
# Loss = 2.9638e-02, PNorm = 34.2176, GNorm = 1.5122, lr_0 = 2.9126e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.075204
#  50%|█████     | 15/30 [00:10<00:10,  1.45it/s]Epoch 15
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.067249
#  53%|█████▎    | 16/30 [00:11<00:10,  1.37it/s]Epoch 16
# Loss = 2.7262e-02, PNorm = 34.2254, GNorm = 0.4222, lr_0 = 2.4709e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.064966
#  57%|█████▋    | 17/30 [00:12<00:09,  1.31it/s]Epoch 17
# Loss = 1.3779e-02, PNorm = 34.2301, GNorm = 0.8317, lr_0 = 2.1544e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.063238
#  60%|██████    | 18/30 [00:12<00:08,  1.35it/s]Epoch 18
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.062209
#  63%|██████▎   | 19/30 [00:13<00:09,  1.20it/s]Epoch 19
# Loss = 2.2175e-02, PNorm = 34.2347, GNorm = 1.1780, lr_0 = 1.8277e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.061001
#  67%|██████▋   | 20/30 [00:14<00:08,  1.17it/s]Epoch 20
# Loss = 2.1519e-02, PNorm = 34.2381, GNorm = 1.5620, lr_0 = 1.5719e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.060365
#  70%|███████   | 21/30 [00:15<00:07,  1.15it/s]Epoch 21
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.063126
#  73%|███████▎  | 22/30 [00:16<00:06,  1.20it/s]Epoch 22
# Loss = 1.7816e-02, PNorm = 34.2411, GNorm = 0.7911, lr_0 = 1.3519e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.058434
#  77%|███████▋  | 23/30 [00:17<00:05,  1.22it/s]Epoch 23
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.059248
#  80%|████████  | 24/30 [00:17<00:04,  1.28it/s]Epoch 24
# Loss = 1.4563e-02, PNorm = 34.2439, GNorm = 0.4038, lr_0 = 1.1469e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.057317
#  83%|████████▎ | 25/30 [00:18<00:03,  1.29it/s]Epoch 25
# Loss = 1.8540e-02, PNorm = 34.2460, GNorm = 1.4413, lr_0 = 1.0000e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.057673
#  87%|████████▋ | 26/30 [00:19<00:03,  1.32it/s]Epoch 26
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.059293
#  90%|█████████ | 27/30 [00:20<00:02,  1.33it/s]Epoch 27
# Loss = 1.4511e-02, PNorm = 34.2485, GNorm = 0.2267, lr_0 = 1.0000e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.057364
#  93%|█████████▎| 28/30 [00:20<00:01,  1.37it/s]Epoch 28
# Loss = 1.6109e-02, PNorm = 34.2508, GNorm = 0.6791, lr_0 = 1.0000e-04
# Loss = 1.1993e-02, PNorm = 34.2509, GNorm = 0.6033, lr_0 = 1.0000e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.055116
#  97%|█████████▋| 29/30 [00:21<00:00,  1.38it/s]Epoch 29
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.056154
# 100%|██████████| 30/30 [00:22<00:00,  1.35it/s]
# Model 0 best validation rmse = 0.055116 on epoch 28
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Model 0 test rmse = 0.100292
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Ensemble test rmse = 0.100292
# Fold 1
# Splitting data with seed 1
# Total size = 390 | train size = 312 | val size = 39 | test size = 39
# Fitting scaler
# Building model 0
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=433, out_features=300, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 355,201
#   0%|          | 0/30 [00:00<?, ?it/s]Epoch 0
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.165141
#   3%|▎         | 1/30 [00:00<00:21,  1.34it/s]Epoch 1
# Loss = 4.1795e-01, PNorm = 34.0376, GNorm = 1.5927, lr_0 = 1.0000e-03
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.141351
#   7%|▋         | 2/30 [00:01<00:20,  1.34it/s]Epoch 2
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.129071
#  10%|█         | 3/30 [00:02<00:19,  1.36it/s]Epoch 3
# Loss = 1.5872e-01, PNorm = 34.0896, GNorm = 2.2771, lr_0 = 8.4834e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.155226
#  13%|█▎        | 4/30 [00:03<00:21,  1.24it/s]Epoch 4
# Loss = 1.4736e-01, PNorm = 34.1228, GNorm = 0.7535, lr_0 = 7.2962e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.129522
#  17%|█▋        | 5/30 [00:03<00:19,  1.27it/s]Epoch 5
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.105419
#  20%|██        | 6/30 [00:04<00:19,  1.23it/s]Epoch 6
# Loss = 9.2302e-02, PNorm = 34.1491, GNorm = 1.6146, lr_0 = 6.2751e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.098700
#  23%|██▎       | 7/30 [00:05<00:18,  1.27it/s]Epoch 7
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.108479
#  27%|██▋       | 8/30 [00:06<00:16,  1.32it/s]Epoch 8
# Loss = 6.9239e-02, PNorm = 34.1743, GNorm = 3.3022, lr_0 = 5.3234e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.086171
#  30%|███       | 9/30 [00:06<00:15,  1.32it/s]Epoch 9
# Loss = 4.1668e-02, PNorm = 34.1901, GNorm = 0.3463, lr_0 = 4.6416e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.084850
#  33%|███▎      | 10/30 [00:07<00:15,  1.33it/s]Epoch 10
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.080244
#  37%|███▋      | 11/30 [00:08<00:15,  1.26it/s]Epoch 11
# Loss = 4.0361e-02, PNorm = 34.2036, GNorm = 1.5672, lr_0 = 3.9377e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.075061
#  40%|████      | 12/30 [00:09<00:14,  1.27it/s]Epoch 12
# Loss = 3.1749e-02, PNorm = 34.2126, GNorm = 3.1962, lr_0 = 3.3866e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.074857
#  43%|████▎     | 13/30 [00:10<00:13,  1.30it/s]Epoch 13
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.072599
#  47%|████▋     | 14/30 [00:10<00:12,  1.30it/s]Epoch 14
# Loss = 2.0363e-02, PNorm = 34.2190, GNorm = 0.2436, lr_0 = 2.9126e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.066238
#  50%|█████     | 15/30 [00:11<00:12,  1.23it/s]Epoch 15
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.063873
#  53%|█████▎    | 16/30 [00:12<00:11,  1.27it/s]Epoch 16
# Loss = 2.2169e-02, PNorm = 34.2257, GNorm = 0.7254, lr_0 = 2.4709e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.063592
#  57%|█████▋    | 17/30 [00:13<00:10,  1.25it/s]Epoch 17
# Loss = 1.8420e-02, PNorm = 34.2305, GNorm = 1.2849, lr_0 = 2.1544e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.072412
#  60%|██████    | 18/30 [00:13<00:08,  1.34it/s]Epoch 18
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.062860
#  63%|██████▎   | 19/30 [00:14<00:08,  1.34it/s]Epoch 19
# Loss = 1.5132e-02, PNorm = 34.2339, GNorm = 1.2577, lr_0 = 1.8277e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.068704
#  67%|██████▋   | 20/30 [00:15<00:07,  1.40it/s]Epoch 20
# Loss = 1.7073e-02, PNorm = 34.2364, GNorm = 0.8561, lr_0 = 1.5719e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.062590
#  70%|███████   | 21/30 [00:16<00:06,  1.38it/s]Epoch 21
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.064174
#  73%|███████▎  | 22/30 [00:16<00:05,  1.44it/s]Epoch 22
# Loss = 1.6229e-02, PNorm = 34.2398, GNorm = 1.5302, lr_0 = 1.3519e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.058672
#  77%|███████▋  | 23/30 [00:17<00:04,  1.46it/s]Epoch 23
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.058450
#  80%|████████  | 24/30 [00:18<00:04,  1.42it/s]Epoch 24
# Loss = 1.3637e-02, PNorm = 34.2419, GNorm = 0.6766, lr_0 = 1.1469e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.058289
#  83%|████████▎ | 25/30 [00:18<00:03,  1.39it/s]Epoch 25
# Loss = 1.0752e-02, PNorm = 34.2435, GNorm = 0.6842, lr_0 = 1.0000e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.056828
#  87%|████████▋ | 26/30 [00:19<00:02,  1.36it/s]Epoch 26
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.056625
#  90%|█████████ | 27/30 [00:20<00:02,  1.32it/s]Epoch 27
# Loss = 1.1614e-02, PNorm = 34.2455, GNorm = 0.7464, lr_0 = 1.0000e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.055838
#  93%|█████████▎| 28/30 [00:21<00:01,  1.30it/s]Epoch 28
# Loss = 1.3119e-02, PNorm = 34.2474, GNorm = 0.6189, lr_0 = 1.0000e-04
# Loss = 9.1975e-03, PNorm = 34.2476, GNorm = 0.7917, lr_0 = 1.0000e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.059112
#  97%|█████████▋| 29/30 [00:21<00:00,  1.37it/s]Epoch 29
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.056155
# 100%|██████████| 30/30 [00:22<00:00,  1.33it/s]
# Model 0 best validation rmse = 0.055838 on epoch 27
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Model 0 test rmse = 0.050819
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Ensemble test rmse = 0.050819
# Fold 2
# Splitting data with seed 2
# Total size = 390 | train size = 312 | val size = 39 | test size = 39
# Fitting scaler
# Building model 0
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=433, out_features=300, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 355,201
#   0%|          | 0/30 [00:00<?, ?it/s]Epoch 0
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.198698
#   3%|▎         | 1/30 [00:01<00:34,  1.20s/it]Epoch 1
# Loss = 3.7305e-01, PNorm = 34.0380, GNorm = 4.0471, lr_0 = 1.0000e-03
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.165529
#   7%|▋         | 2/30 [00:02<00:30,  1.10s/it]Epoch 2
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.171133
#  10%|█         | 3/30 [00:03<00:26,  1.01it/s]Epoch 3
# Loss = 1.4358e-01, PNorm = 34.0912, GNorm = 1.3859, lr_0 = 8.4834e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.131954
#  13%|█▎        | 4/30 [00:03<00:24,  1.05it/s]Epoch 4
# Loss = 1.4428e-01, PNorm = 34.1190, GNorm = 1.3901, lr_0 = 7.2962e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.117991
#  17%|█▋        | 5/30 [00:04<00:22,  1.11it/s]Epoch 5
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.102099
#  20%|██        | 6/30 [00:05<00:20,  1.18it/s]Epoch 6
# Loss = 8.0058e-02, PNorm = 34.1417, GNorm = 1.5776, lr_0 = 6.2751e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.093086
#  23%|██▎       | 7/30 [00:06<00:19,  1.20it/s]Epoch 7
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.090354
#  27%|██▋       | 8/30 [00:07<00:17,  1.26it/s]Epoch 8
# Loss = 6.8895e-02, PNorm = 34.1629, GNorm = 3.0916, lr_0 = 5.3234e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.081313
#  30%|███       | 9/30 [00:07<00:16,  1.31it/s]Epoch 9
# Loss = 5.4840e-02, PNorm = 34.1760, GNorm = 3.1879, lr_0 = 4.6416e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.083599
#  33%|███▎      | 10/30 [00:08<00:14,  1.35it/s]Epoch 10
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.069874
#  37%|███▋      | 11/30 [00:09<00:13,  1.36it/s]Epoch 11
# Loss = 4.5203e-02, PNorm = 34.1893, GNorm = 2.5113, lr_0 = 3.9377e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.070037
#  40%|████      | 12/30 [00:09<00:13,  1.33it/s]Epoch 12
# Loss = 3.3131e-02, PNorm = 34.1986, GNorm = 1.0398, lr_0 = 3.3866e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.065953
#  43%|████▎     | 13/30 [00:10<00:12,  1.35it/s]Epoch 13
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.068254
#  47%|████▋     | 14/30 [00:11<00:11,  1.36it/s]Epoch 14
# Loss = 2.3628e-02, PNorm = 34.2055, GNorm = 0.5169, lr_0 = 2.9126e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.062620
#  50%|█████     | 15/30 [00:12<00:11,  1.25it/s]Epoch 15
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.058199
#  53%|█████▎    | 16/30 [00:13<00:10,  1.28it/s]Epoch 16
# Loss = 1.6729e-02, PNorm = 34.2116, GNorm = 1.2696, lr_0 = 2.4709e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.057762
#  57%|█████▋    | 17/30 [00:13<00:09,  1.30it/s]Epoch 17
# Loss = 2.2852e-02, PNorm = 34.2156, GNorm = 0.3260, lr_0 = 2.1544e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.055195
#  60%|██████    | 18/30 [00:14<00:09,  1.32it/s]Epoch 18
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.054008
#  63%|██████▎   | 19/30 [00:15<00:08,  1.35it/s]Epoch 19
# Loss = 2.0986e-02, PNorm = 34.2200, GNorm = 0.6456, lr_0 = 1.8277e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.053400
#  67%|██████▋   | 20/30 [00:16<00:07,  1.34it/s]Epoch 20
# Loss = 1.9108e-02, PNorm = 34.2232, GNorm = 0.7060, lr_0 = 1.5719e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.052595
#  70%|███████   | 21/30 [00:16<00:06,  1.35it/s]Epoch 21
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.055991
#  73%|███████▎  | 22/30 [00:17<00:05,  1.43it/s]Epoch 22
# Loss = 2.0893e-02, PNorm = 34.2259, GNorm = 1.1869, lr_0 = 1.3519e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.052067
#  77%|███████▋  | 23/30 [00:18<00:05,  1.38it/s]Epoch 23
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.056932
#  80%|████████  | 24/30 [00:18<00:04,  1.37it/s]Epoch 24
# Loss = 2.1024e-02, PNorm = 34.2286, GNorm = 1.8905, lr_0 = 1.1469e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.058807
#  83%|████████▎ | 25/30 [00:19<00:03,  1.40it/s]Epoch 25
# Loss = 2.0197e-02, PNorm = 34.2306, GNorm = 0.7268, lr_0 = 1.0000e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.047108
#  87%|████████▋ | 26/30 [00:20<00:02,  1.42it/s]Epoch 26
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.046320
#  90%|█████████ | 27/30 [00:20<00:02,  1.40it/s]Epoch 27
# Loss = 2.3995e-02, PNorm = 34.2328, GNorm = 0.6444, lr_0 = 1.0000e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.045562
#  93%|█████████▎| 28/30 [00:21<00:01,  1.41it/s]Epoch 28
# Loss = 1.4499e-02, PNorm = 34.2348, GNorm = 0.3727, lr_0 = 1.0000e-04
# Loss = 4.4230e-02, PNorm = 34.2350, GNorm = 1.6247, lr_0 = 1.0000e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.045682
#  97%|█████████▋| 29/30 [00:22<00:00,  1.42it/s]Epoch 29
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.047655
# 100%|██████████| 30/30 [00:22<00:00,  1.31it/s]
# Model 0 best validation rmse = 0.045562 on epoch 27
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Model 0 test rmse = 0.055898
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Ensemble test rmse = 0.055898
# Fold 3
# Splitting data with seed 3
# Total size = 390 | train size = 312 | val size = 39 | test size = 39
# Fitting scaler
# ...
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Model 0 test rmse = 0.056670
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Ensemble test rmse = 0.056670
# Fold 4
# Splitting data with seed 4
# Total size = 390 | train size = 312 | val size = 39 | test size = 39
# Fitting scaler
# Building model 0
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=433, out_features=300, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 355,201
#   0%|          | 0/30 [00:00<?, ?it/s]Epoch 0
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.233935
#   3%|▎         | 1/30 [00:00<00:26,  1.09it/s]Epoch 1
# Loss = 4.6429e-01, PNorm = 34.0363, GNorm = 4.3415, lr_0 = 1.0000e-03
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.168265
#   7%|▋         | 2/30 [00:01<00:25,  1.11it/s]Epoch 2
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.141788
#  10%|█         | 3/30 [00:02<00:22,  1.19it/s]Epoch 3
# Loss = 1.7557e-01, PNorm = 34.0811, GNorm = 1.0197, lr_0 = 8.4834e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.127522
#  13%|█▎        | 4/30 [00:03<00:20,  1.27it/s]Epoch 4
# Loss = 1.5640e-01, PNorm = 34.1123, GNorm = 2.7805, lr_0 = 7.2962e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.123559
#  17%|█▋        | 5/30 [00:04<00:19,  1.29it/s]Epoch 5
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.104121
#  20%|██        | 6/30 [00:04<00:18,  1.27it/s]Epoch 6
# Loss = 1.1123e-01, PNorm = 34.1401, GNorm = 0.5744, lr_0 = 6.2751e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.097648
#  23%|██▎       | 7/30 [00:05<00:18,  1.24it/s]Epoch 7
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.088834
#  27%|██▋       | 8/30 [00:06<00:18,  1.17it/s]Epoch 8
# Loss = 7.7614e-02, PNorm = 34.1661, GNorm = 0.6865, lr_0 = 5.3234e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.082419
#  30%|███       | 9/30 [00:07<00:18,  1.14it/s]Epoch 9
# Loss = 5.4041e-02, PNorm = 34.1838, GNorm = 1.3418, lr_0 = 4.6416e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.086506
#  33%|███▎      | 10/30 [00:08<00:16,  1.20it/s]Epoch 10
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.073704
#  37%|███▋      | 11/30 [00:09<00:15,  1.20it/s]Epoch 11
# Loss = 4.7097e-02, PNorm = 34.1957, GNorm = 4.5539, lr_0 = 3.9377e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.090654
#  40%|████      | 12/30 [00:10<00:15,  1.14it/s]Epoch 12
# Loss = 5.6615e-02, PNorm = 34.2048, GNorm = 3.8230, lr_0 = 3.3866e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.062653
#  43%|████▎     | 13/30 [00:10<00:14,  1.17it/s]Epoch 13
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.067393
#  47%|████▋     | 14/30 [00:11<00:13,  1.22it/s]Epoch 14
# Loss = 3.6112e-02, PNorm = 34.2124, GNorm = 1.6932, lr_0 = 2.9126e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.066322
#  50%|█████     | 15/30 [00:12<00:12,  1.25it/s]Epoch 15
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.064946
#  53%|█████▎    | 16/30 [00:13<00:10,  1.32it/s]Epoch 16
# Loss = 3.3403e-02, PNorm = 34.2199, GNorm = 1.1806, lr_0 = 2.4709e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.061870
#  57%|█████▋    | 17/30 [00:13<00:10,  1.29it/s]Epoch 17
# Loss = 2.4763e-02, PNorm = 34.2249, GNorm = 0.7020, lr_0 = 2.1544e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.062841
#  60%|██████    | 18/30 [00:14<00:09,  1.30it/s]Epoch 18
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.062351
#  63%|██████▎   | 19/30 [00:15<00:08,  1.27it/s]Epoch 19
# Loss = 2.0723e-02, PNorm = 34.2294, GNorm = 0.6583, lr_0 = 1.8277e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.062351
#  67%|██████▋   | 20/30 [00:16<00:07,  1.30it/s]Epoch 20
# Loss = 1.8998e-02, PNorm = 34.2329, GNorm = 0.3751, lr_0 = 1.5719e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.059542
#  70%|███████   | 21/30 [00:17<00:06,  1.29it/s]Epoch 21
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.059659
#  73%|███████▎  | 22/30 [00:17<00:05,  1.34it/s]Epoch 22
# Loss = 1.7906e-02, PNorm = 34.2358, GNorm = 0.1906, lr_0 = 1.3519e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.060171
#  77%|███████▋  | 23/30 [00:18<00:05,  1.35it/s]Epoch 23
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.059128
#  80%|████████  | 24/30 [00:19<00:04,  1.34it/s]Epoch 24
# Loss = 2.5433e-02, PNorm = 34.2387, GNorm = 0.2526, lr_0 = 1.1469e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.060341
#  83%|████████▎ | 25/30 [00:19<00:03,  1.33it/s]Epoch 25
# Loss = 1.7791e-02, PNorm = 34.2406, GNorm = 0.6430, lr_0 = 1.0000e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.060127
#  87%|████████▋ | 26/30 [00:20<00:03,  1.27it/s]Epoch 26
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.058273
#  90%|█████████ | 27/30 [00:21<00:02,  1.24it/s]Epoch 27
# Loss = 1.5250e-02, PNorm = 34.2429, GNorm = 0.9804, lr_0 = 1.0000e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.058335
#  93%|█████████▎| 28/30 [00:22<00:01,  1.27it/s]Epoch 28
# Loss = 1.6483e-02, PNorm = 34.2458, GNorm = 0.5621, lr_0 = 1.0000e-04
# Loss = 7.1196e-03, PNorm = 34.2460, GNorm = 1.3939, lr_0 = 1.0000e-04
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.059827
#  97%|█████████▋| 29/30 [00:23<00:00,  1.26it/s]Epoch 29
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.059045
# 100%|██████████| 30/30 [00:24<00:00,  1.25it/s]
# Model 0 best validation rmse = 0.058273 on epoch 26
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Model 0 test rmse = 0.067995
# c:\Users\wanne\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Ensemble test rmse = 0.067995
# 5-fold cross validation
# 	Seed 0 ==> test rmse = 0.100292
# 	Seed 1 ==> test rmse = 0.050819
# 	Seed 2 ==> test rmse = 0.055898
# 	Seed 3 ==> test rmse = 0.056670
# 	Seed 4 ==> test rmse = 0.067995
# Overall test rmse = 0.066335 +/- 0.017882
# Elapsed time = 0:02:05
