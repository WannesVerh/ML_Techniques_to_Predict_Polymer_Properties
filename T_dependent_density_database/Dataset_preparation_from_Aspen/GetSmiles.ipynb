# %%
import pandas as pd
import cirpy
# Out:
# C:\Users\wanne\AppData\Local\Temp\ipykernel_21792\2516213697.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('./csv_files_without_Smiles/1_alkenes.csv')

#keep trace on which identifier was the most efficient
name_found = 0
casnr_found = 0
exceptions = 0

smiles = []

#we have 802 samples is this df
for i in range(df.shape[0]):
    if i in [100, 200, 300, 400, 500, 600, 700]:
        print("genereting smiles string for compound", i)

    comp_name = df['Component name'][i]
    casnr = df['CAS number'][i]

    #exceptionnally cirpy returns an error than jut add none
    try: 
        smile = cirpy.resolve(comp_name, 'smiles')
    except:
        smile = None
    try: 
        smile2 = cirpy.resolve(casnr, 'smiles')
    except:
        smile2 = None
    if smile == None and smile2 == None:
        exceptions +=1 

    #use some if statements to add the rigth value
    #if both retun None or the rigth smiles string add it
    if smile == smile2:
        smiles.append(smile)
        name_found +=1
        casnr_found +=1
    
    # if they both return a diffrent smile add the smile string generated from the casnr
    elif smile != None and smile2 != None:
        smiles.append(smile2)
    
    #if only smile is None add smile2
    elif smile == None:
        smiles.append(smile2)
        casnr_found +=1

    else:
        smiles.append(smile)
        name_found +=1

# %%
print("amount found by compound name:", name_found)
print("amount found by casnr:", casnr_found)
print("amount of errors", exceptions)
# Out:
# amount found by compound name: 30
# amount found by casnr: 24
# amount of errors 0

# %%
df= pd.read_csv('./csv_files_without_Smiles/1_alkenes.csv')

# %%
df.insert(3,"smiles",smiles,True)
#df.to_csv('../csv_files/PE_2_3_combined_final.csv')

# %%
df
# Out:
#    Component ID     Component name  CAS number  \
# 0      ETHYL-01           ETHYLENE     74-85-1
# 1      PROPY-01          PROPYLENE    115-07-1
# 2      1-BUT-01           1-BUTENE    106-98-9
# 3      1-PEN-01          1-PENTENE    109-67-1
# 4      1-HEX-01           1-HEXENE    592-41-6
# 5      1-HEP-01          1-HEPTENE    592-76-7
# 6      1-OCT-01           1-OCTENE    111-66-0
# 7      1-NON-01           1-NONENE    124-11-8
# 8      1-DEC-01           1-DECENE    872-05-9
# 9      1-UND-01         1-UNDECENE    821-95-4
# 10     1-DOD-01         1-DODECENE    112-41-4
# 11     1-TRI-01        1-TRIDECENE   2437-56-1
# 12     1-TET-01      1-TETRADECENE   1120-36-1
# 13     1-PEN-02      1-PENTADECENE  13360-61-7
# 14     1-HEX-02       1-HEXADECENE    629-73-2
# 15     1-HEP-02      1-HEPTADECENE   6765-39-5
# 16     1-OCT-02       1-OCTADECENE    112-88-9
# 17     1-NON-02       1-NONADECENE  18435-45-5
# 18     1-EIC-01         1-EICOSENE   3452-07-1
# 19     1-HEN-01      1-HENEICOSENE   1599-68-4
# 20     1-DOC-01         1-DOCOSENE   1599-67-3
# 21     1-TRI-02        1-TRICOSENE  18835-32-0
# 22     1-TET-02      1-TETRACOSENE  10192-32-2
# 23     1-HEX-03       1-HEXACOSENE  18835-33-1
# 24     1-HEP-03      1-HEPTACOSENE  15306-27-1
# 25     1-OCT-03       1-OCTACOSENE  18835-34-2
# 26     1-NON-03       1-NONACOSENE  18835-35-3
# 27     1-TRI-03      1-TRIACONTENE  18435-53-5
# 28     1-HEX-04  1-HEXATRIACONTENE  61868-14-2
# 29     1-TET-03     1-TETRACONTENE  61868-18-6
#
#                                        smiles
# 0                                         C=C
# 1                                        CC=C
# 2                                       CCC=C
# 3                                      CCCC=C
# 4                                     CCCCC=C
# 5                                    CCCCCC=C
# 6                                   CCCCCCC=C
# 7                                  CCCCCCCC=C
# 8                                 CCCCCCCCC=C
# 9                                CCCCCCCCCC=C
# 10                              CCCCCCCCCCC=C
# 11                             CCCCCCCCCCCC=C
# 12                            CCCCCCCCCCCCC=C
# 13                           CCCCCCCCCCCCCC=C
# 14                          CCCCCCCCCCCCCCC=C
# 15                         CCCCCCCCCCCCCCCC=C
# 16                        CCCCCCCCCCCCCCCCC=C
# 17                       CCCCCCCCCCCCCCCCCC=C
# 18                      CCCCCCCCCCCCCCCCCCC=C
# 19                     CCCCCCCCCCCCCCCCCCCC=C
# 20                    CCCCCCCCCCCCCCCCCCCCC=C
# 21                   CCCCCCCCCCCCCCCCCCCCCC=C
# 22                  CCCCCCCCCCCCCCCCCCCCCCC=C
# 23                CCCCCCCCCCCCCCCCCCCCCCCCC=C
# 24               CCCCCCCCCCCCCCCCCCCCCCCCCC=C
# 25              CCCCCCCCCCCCCCCCCCCCCCCCCCC=C
# 26             CCCCCCCCCCCCCCCCCCCCCCCCCCCC=C
# 27            CCCCCCCCCCCCCCCCCCCCCCCCCCCCC=C
# 28      CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC=C
# 29  CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC=C

# %%
data = df.drop(columns=[])
idx = []

#find the molecules which did not return a smile string
for i, smile in enumerate(data.smiles):
    if smile == None:
        idx.append(i)

#remove them
data = data.drop(idx)

# %%
data
# Out:
#    Component ID     Component name  CAS number  \
# 0      ETHYL-01           ETHYLENE     74-85-1
# 1      PROPY-01          PROPYLENE    115-07-1
# 2      1-BUT-01           1-BUTENE    106-98-9
# 3      1-PEN-01          1-PENTENE    109-67-1
# 4      1-HEX-01           1-HEXENE    592-41-6
# 5      1-HEP-01          1-HEPTENE    592-76-7
# 6      1-OCT-01           1-OCTENE    111-66-0
# 7      1-NON-01           1-NONENE    124-11-8
# 8      1-DEC-01           1-DECENE    872-05-9
# 9      1-UND-01         1-UNDECENE    821-95-4
# 10     1-DOD-01         1-DODECENE    112-41-4
# 11     1-TRI-01        1-TRIDECENE   2437-56-1
# 12     1-TET-01      1-TETRADECENE   1120-36-1
# 13     1-PEN-02      1-PENTADECENE  13360-61-7
# 14     1-HEX-02       1-HEXADECENE    629-73-2
# 15     1-HEP-02      1-HEPTADECENE   6765-39-5
# 16     1-OCT-02       1-OCTADECENE    112-88-9
# 17     1-NON-02       1-NONADECENE  18435-45-5
# 18     1-EIC-01         1-EICOSENE   3452-07-1
# 19     1-HEN-01      1-HENEICOSENE   1599-68-4
# 20     1-DOC-01         1-DOCOSENE   1599-67-3
# 21     1-TRI-02        1-TRICOSENE  18835-32-0
# 22     1-TET-02      1-TETRACOSENE  10192-32-2
# 23     1-HEX-03       1-HEXACOSENE  18835-33-1
# 24     1-HEP-03      1-HEPTACOSENE  15306-27-1
# 25     1-OCT-03       1-OCTACOSENE  18835-34-2
# 26     1-NON-03       1-NONACOSENE  18835-35-3
# 27     1-TRI-03      1-TRIACONTENE  18435-53-5
# 28     1-HEX-04  1-HEXATRIACONTENE  61868-14-2
# 29     1-TET-03     1-TETRACONTENE  61868-18-6
#
#                                        smiles
# 0                                         C=C
# 1                                        CC=C
# 2                                       CCC=C
# 3                                      CCCC=C
# 4                                     CCCCC=C
# 5                                    CCCCCC=C
# 6                                   CCCCCCC=C
# 7                                  CCCCCCCC=C
# 8                                 CCCCCCCCC=C
# 9                                CCCCCCCCCC=C
# 10                              CCCCCCCCCCC=C
# 11                             CCCCCCCCCCCC=C
# 12                            CCCCCCCCCCCCC=C
# 13                           CCCCCCCCCCCCCC=C
# 14                          CCCCCCCCCCCCCCC=C
# 15                         CCCCCCCCCCCCCCCC=C
# 16                        CCCCCCCCCCCCCCCCC=C
# 17                       CCCCCCCCCCCCCCCCCC=C
# 18                      CCCCCCCCCCCCCCCCCCC=C
# 19                     CCCCCCCCCCCCCCCCCCCC=C
# 20                    CCCCCCCCCCCCCCCCCCCCC=C
# 21                   CCCCCCCCCCCCCCCCCCCCCC=C
# 22                  CCCCCCCCCCCCCCCCCCCCCCC=C
# 23                CCCCCCCCCCCCCCCCCCCCCCCCC=C
# 24               CCCCCCCCCCCCCCCCCCCCCCCCCC=C
# 25              CCCCCCCCCCCCCCCCCCCCCCCCCCC=C
# 26             CCCCCCCCCCCCCCCCCCCCCCCCCCCC=C
# 27            CCCCCCCCCCCCCCCCCCCCCCCCCCCCC=C
# 28      CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC=C
# 29  CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC=C

# %%
data.to_csv('./csv_files_with_Smiles/test.csv', index=False)
