# %%
import pandas as pd
# Out:
# C:\Users\wanne\AppData\Local\Temp\ipykernel_19276\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df1 = pd.read_csv('../csv_files/Combined_dens_Dataset.csv')
df1
# Out:
#                                                   smiles  temp     density
# 0                                                    C=C    25    0.001153
# 1                                                    C=C    50    0.001063
# 2                                                    C=C    75    0.000986
# 3                                                    C=C   100    0.000919
# 4                                                    C=C   125    0.000861
# ...                                                  ...   ...         ...
# 13333  CC(CCC(CCCCC(CCC(C)CC(C)(C)C)CCC(C)CC(C)(C)C)C...   400  648.460177
# 13334  CC(CCC(CCCCC(CCC(C)CC(C)(C)C)CCC(C)CC(C)(C)C)C...   425  614.306773
# 13335  CC(CCC(CCCCC(CCC(C)CC(C)(C)C)CCC(C)CC(C)(C)C)C...   450  577.509165
# 13336  CC(CCC(CCCCC(CCC(C)CC(C)(C)C)CCC(C)CC(C)(C)C)C...   475  537.011224
# 13337  CC(CCC(CCCCC(CCC(C)CC(C)(C)C)CCC(C)CC(C)(C)C)C...   500   10.614285
#
# [13338 rows x 3 columns]

# %%
df = df1[df1.temp == 25]
df
# Out:
#                                                   smiles  temp      density
# 0                                                    C=C    25     0.001153
# 20                                                  CC=C    25     0.001743
# 40                                                 CCC=C    25     0.002347
# 60                                                CCCC=C    25     0.634840
# 80                                               CCCCC=C    25     0.669333
# ...                                                  ...   ...          ...
# 13238                 CCCCCCCCCCCCCCCC(CCCCCCCC)CCCCCCCC    25   864.118765
# 13258               CCCCCCCCCCCCCCCCCC(CCCCCCCC)CCCCCCCC    25  1022.345230
# 13278               CCCCCCCCCCCCCC(CCCCCCCCCC)CCCCCCCCCC    25   962.603741
# 13298             CCCCCCCCCCCCC(CCCCCCCCCCC)CCCCCCCCCCCC    25   907.463184
# 13318  CC(CCC(CCCCC(CCC(C)CC(C)(C)C)CCC(C)CC(C)(C)C)C...    25  1038.774850
#
# [670 rows x 3 columns]

# %%
df.to_csv('../csv_files/RoomTemp_dens_Dataset.csv', index=False)
